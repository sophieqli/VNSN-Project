# %% [markdown]
# Create a shortcut to the shared `Colab_notebooks_VNSN` folder in your own google drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab_notebooks_VNSN/TokenSkip
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1ZetTiZovDkYP2jJ2GKLiESjtzgC5VDVO/Colab_notebooks_VNSN/TokenSkip
# assets		 datasets	  evaluation.py		     outputs
# configs		 drift_scorer.py  get_llamafactory_input.py  __pycache__
# custom_gen.py	 eval		  LICENSE		     Readme.md
# data_processing  eval.sh	  LLMLingua.py		     requirements.txt

# %%
# !pip install -r /content/drive/MyDrive/Colab_notebooks_VNSN/TokenSkip/requirements.txt
# !pip install -r requirements.txt

# %%
from huggingface_hub import login
login()

# %%
# !bash /content/drive/MyDrive/Colab_notebooks_VNSN/TokenSkip/eval.sh
# !bash eval.sh
# Out:
# 2025-07-29 08:11:27.222017: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753776687.253899    3865 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753776687.263869    3865 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-29 08:11:27.294703: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
